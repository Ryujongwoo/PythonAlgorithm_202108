# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
# 타겟 사이트 주소 만들기
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=1 =>   1 ~  50
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=2 =>  51 ~ 100
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=3 => 101 ~ 150
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=4 => 151 ~ 200
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
for i in range(1, 5):
    # targetSite = url + str(i)
    targetSite = '{}{}'.format(url, i)
    print(targetSite)
# Out:
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=1
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=2
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=3
# https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg=4

# %%
# 노래 제목 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    # print(request)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')
    # print(soup)
    
    titles = soup.findAll('a', {'class': 'title ellipsis'})
    # print(titles)
    # print(len(titles))
    
    for i in range(len(titles)):
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip())) # 사용가능
        # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.split('\n')[-1].strip())) # 사용가능
        print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip().split('\n')[0])) # 사용가능
# Out:
#   1위 Stay
#   2위 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   3위 신호등
#   4위 OHAYO MY NIGHT
#   5위 Queendom
#   6위 바라만 본다
#   7위 Next Level
#   8위 낙하 (With 아이유)
#   9위 고백
#  10위 Weekend
#  11위 Bad Habits
#  12위 DUMB DUMB
#  13위 Permission to Dance
#  14위 좋아좋아
#  15위 Butter
#  16위 Peaches (Feat. Daniel Caesar & Giveon)
#  17위 비와 당신
#  18위 헤픈 우연
#  19위 다정히 내 이름을 부르면
#  20위 Dynamite
#  21위 라일락
#  22위 비가 오는 날엔 (2021)
#  23위 롤린 (Rollin')
#  24위 Celebrity
#  25위 Dun Dun Dance
#  26위 하루만 더
#  27위 치맛바람 (Chi Mat Ba Ram)
#  28위 이제 나만 믿어요
#  29위 고백
#  30위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  31위 수취인불명
#  32위 Alcohol-Free
#  33위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  34위 운전만해 (We Ride)
#  35위 안녕 (Hello)
#  36위 가을 우체국 앞에서
#  37위 사진을 보다가
#  38위 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  39위 다시 사랑한다면 (김필 Ver.)
#  40위 ASAP
#  41위 Off My Face
#  42위 At My Worst
#  43위 Timeless
#  44위 별빛 같은 나의 사랑아
#  45위 아로하
#  46위 상상더하기
#  47위 에잇 (Prod. & Feat. SUGA of BTS)
#  48위 HERO
#  49위 내 손을 잡아
#  50위 여전히 아름다운지

# %%
# 아티스트 크롤링
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 2):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    artists = soup.findAll('a', {'class', 'artist ellipsis'})
    # print(artists)
    # print(len(artists))
    
    for i in range(5, len(artists)):
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip())) # 사용가능
        # print('{0:3d}위 {1}'.format(i - 4, artists[i].text.split('\n')[0])) # 사용가능
        print('{0:3d}위 {1}'.format(i - 4, artists[i].text.strip().split('\n')[0])) # 사용가능
# Out:
#   1위 The Kid LAROI & Justin Bieber
#   2위 케이윌 (K.Will)
#   3위 이무진
#   4위 디핵 (D-Hack) & PATEKO
#   5위 Red Velvet (레드벨벳)
#   6위 MSG워너비 (M.O.M)
#   7위 aespa
#   8위 멜로망스 (MeloMance)
#   9위 AKMU (악뮤)
#  10위 Ed Sheeran
#  11위 태연 (TAEYEON)
#  12위 전소미
#  13위 방탄소년단
#  14위 조정석
#  15위 방탄소년단
#  16위 Justin Bieber
#  17위 이무진
#  18위 헤이즈 (Heize)
#  19위 경서예지 & 전건호
#  20위 헤이즈 (Heize)
#  21위 방탄소년단
#  22위 브레이브걸스 (Brave girls)
#  23위 아이유 (IU)
#  24위 임영웅
#  25위 오마이걸 (OH MY GIRL)
#  26위 빅마마 (Big Mama)
#  27위 아이유 (IU)
#  28위 브레이브걸스 (Brave girls)
#  29위 10CM
#  30위 에픽하이 (EPIK HIGH)
#  31위 매드 클라운 (Mad Clown) & 이해리 (다비치)
#  32위 Jawsh 685 & Jason Derulo & 방탄소년단
#  33위 임영웅
#  34위 호미들
#  35위 TWICE (트와이스)
#  36위 임영웅
#  37위 임영웅
#  38위 다비치
#  39위 브레이브걸스 (Brave girls)
#  40위 김대명
#  41위 조이 (JOY)
#  42위 STAYC (스테이씨)
#  43위 Justin Bieber
#  44위 임영웅
#  45위 임영웅
#  46위 라붐 (LABOUM)
#  47위 임영웅
#  48위 Pink Sweat$
#  49위 SG워너비
#  50위 임영웅

# %%
# 크롤링한 데이터를 리스트에 저장한다.
genie = [] # 200곡의 정보를 기억할 빈 리스트를 선언한다.
url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20210903&hh=20&rtm=Y&pg='
header = {"User-agent": "Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko"}
for i in range(1, 5):
    targetSite = '{}{}'.format(url, i)
    request = requests.get(targetSite, headers=header)
    html = request.text
    soup = BeautifulSoup(html, 'html.parser')

    titles = soup.findAll('a', {'class': 'title ellipsis'})
    artists = soup.findAll('a', {'class', 'artist ellipsis'})
    
    for j in range(50):
        genie.append(
            (artists[j + 5].text.strip().split('\n')[0], titles[j].text.strip().split('\n')[0])
        )
# print(len(genie))
print(genie)
# Out:
# [('The Kid LAROI & Justin Bieber', 'Stay'), ('케이윌 (K.Will)', '시간을 거슬러 (낮에 뜨는 달 X 케이윌)'), ('이무진', '신호등'), ('디핵 (D-Hack) & PATEKO', 'OHAYO MY NIGHT'), ('Red Velvet (레드벨벳)', 'Queendom'), ('MSG워너비 (M.O.M)', '바라만 본다'), ('aespa', 'Next Level'), ('멜로망스 (MeloMance)', '고백'), ('AKMU (악뮤)', '낙하 (With 아이유)'), ('Ed Sheeran', 'Bad Habits'), ('태연 (TAEYEON)', 'Weekend'), ('전소미', 'DUMB DUMB'), ('방탄소년단', 'Permission to Dance'), ('조정석', '좋아좋아'), ('방탄소년단', 'Butter'), ('Justin Bieber', 'Peaches (Feat. Daniel Caesar & Giveon)'), ('이무진', '비와 당신'), ('헤이즈 (Heize)', '헤픈 우연'), ('경서예지 & 전건호', '다정히 내 이름을 부르면'), ('헤이즈 (Heize)', '비가 오는 날엔 (2021)'), ('방탄소년단', 'Dynamite'), ('브레이브걸스 (Brave girls)', "롤린 (Rollin')"), ('아이유 (IU)', '라일락'), ('임영웅', '이제 나만 믿어요'), ('오마이걸 (OH MY GIRL)', 'Dun Dun Dance'), ('빅마마 (Big Mama)', '하루만 더'), ('아이유 (IU)', 'Celebrity'), ('브레이브걸스 (Brave girls)', '치맛바람 (Chi Mat Ba Ram)'), ('10CM', '고백'), ('에픽하이 (EPIK HIGH)', '비 오는 날 듣기 좋은 노래 (Feat. Colde)'), ('매드 클라운 (Mad Clown) & 이해리 (다비치)', '수취인불명'), ('Jawsh 685 & Jason Derulo & 방탄소년단', 'Savage Love (Laxed - Siren Beat) (BTS Remix)'), ('임영웅', '다시 사랑한다면 (김필 Ver.)'), ('호미들', '사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)'), ('TWICE (트와이스)', 'Alcohol-Free'), ('임영웅', '별빛 같은 나의 사랑아'), ('임영웅', 'HERO'), ('다비치', '사진을 보다가'), ('브레이브걸스 (Brave girls)', '운전만해 (We Ride)'), ('김대명', '가을 우체국 앞에서'), ('조이 (JOY)', '안녕 (Hello)'), ('STAYC (스테이씨)', 'ASAP'), ('Justin Bieber', 'Off My Face'), ('임영웅', '그대라는 사치'), ('임영웅', '끝사랑'), ('라붐 (LABOUM)', '상상더하기'), ('임영웅', 'Bk Love'), ('Pink Sweat$', 'At My Worst'), ('SG워너비', 'Timeless'), ('임영웅', '잊었니'), ('Anne-Marie', '2002'), ('아이유 (IU)', '내 손을 잡아'), ('세븐틴 (SEVENTEEN)', '여전히 아름다운지'), ('송이한', '밝게 빛나는 별이 되어 비춰줄게'), ('조정석', '아로하'), ('방탄소년단', '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)'), ('장범준', '추적이는 여름 비가 되어'), ('아이유 (IU)', 'Blueming'), ('ASH ISLAND', '멜로디'), ('Stray Kids (스트레이 키즈)', '소리꾼'), ('etham', '12 : 45 (Stripped)'), ('임영웅', '미워요'), ('미도와 파라솔', '이젠 잊기로 해요 (Drama Ver.)'), ('MSG워너비 (정상동기)', '나를 아는 사람'), ('장범준', '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야'), ('경서', '밤하늘의 별을 (2020)'), ('창모 (CHANGMO)', 'METEOR'), ('BLACKPINK', 'Lovesick Girls'), ('임영웅', '계단말고 엘리베이터'), ('임영웅', '사랑의 아픔 딛고'), ('아이유 (IU)', '어푸 (Ah puh)'), ('폴킴', '모든 날, 모든 순간 (Every day, Every Moment)'), ('환희', '오늘은 가지마 (2021)'), ('Doja Cat', 'Kiss Me More (Feat. SZA)'), ('김종국', '눈물을 훔친다 (금혼령 X 김종국)'), ('임영웅', '목로주점'), ('아이유 (IU)', '에잇 (Prod. & Feat. SUGA of BTS)'), ('방탄소년단', 'Life Goes On'), ('방탄소년단', '봄날'), ('미도와 파라솔', '슈퍼스타'), ('미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM)', 'VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)'), ('AKMU (악뮤)', '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지'), ('오마이걸 (OH MY GIRL)', 'Dolphin'), ('MSG워너비', '상상더하기'), ('양요섭 & 정은지', 'LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)'), ('Standing Egg (스탠딩 에그)', '오래된 노래'), ('John K', 'parachute'), ('Bruno Mars & Anderson .Paak & Silk Sonic', 'Leave The Door Open'), ('장범준', '잠이 오질 않네요'), ('Maroon 5', 'Memories'), ('백지영 & 이홍기 (FT아일랜드)', '다시 사랑할 수 있을까'), ('산들', '취기를 빌려 (취향저격 그녀 X 산들)'), ('장범준', '고백'), ('경서예지', '은하수를 닮은 너에게 (Feat. 몰리디)'), ('정동하', '추억은 만남보다 이별에 남아'), ('장범준', '나는 너 좋아'), ('Tones And I', 'Dance Monkey'), ('마크툽 (Maktub)', '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)'), ('이예준', '그날에 나는 맘이 편했을까'), ('미도와 파라솔', '벌써 일년 (Drama Ver.)'), ('선우정아', '도망가자 (Run With Me)'), ('Christopher', 'Bad'), ('PATEKO (파테코)', 'Rainy day (Feat. ASH ISLAND & Skinny Brown)'), ('아이유 (IU)', 'Coin'), ('원슈타인', '밤이 되니까'), ('카더가든', '가까운 듯 먼 그대여'), ('전미도', '사랑하게 될 줄 알았어'), ('Sam Ryder', 'Tiny Riot'), ('김호중', '만개 (Prod. 신지후)'), ('정경호', '회상'), ('10CM', '이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)'), ('SG워너비', '라라라'), ('로꼬 & 이성경', '러브 (Prod. by 로코베리)'), ('Dua Lipa', "Don't Start Now"), ('#안녕', '너의 번호를 누르고 (Prod. by 영화처럼)'), ('숀 (SHAUN)', 'Way Back Home'), ('Stellar', 'Ashes'), ('Lauv', 'Paris In The Rain'), ('미도와 파라솔', '넌 내게 반했어 (Drama Ver.)'), ('헤이즈 (Heize)', '비도 오고 그래서 (Feat. 신용재)'), ('김호중', '나보다 더 사랑해요'), ('경서예지', '사실 나는 (Feat. 전건호)'), ('방탄소년단', 'IDOL'), ('허각', '우린 어쩌다 헤어진 걸까'), ('Ed Sheeran', 'Shape Of You'), ('방탄소년단', ...

# %%
print('{} 현재'.format(dt.now()))
for i in range(200):
    print('{0:3d}위 {1} - {2}'.format(i + 1, genie[i][0], genie[i][1]))
# Out:
# 2021-09-03 21:25:56.385618 현재
#   1위 The Kid LAROI & Justin Bieber - Stay
#   2위 케이윌 (K.Will) - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   3위 이무진 - 신호등
#   4위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
#   5위 Red Velvet (레드벨벳) - Queendom
#   6위 MSG워너비 (M.O.M) - 바라만 본다
#   7위 aespa - Next Level
#   8위 멜로망스 (MeloMance) - 고백
#   9위 AKMU (악뮤) - 낙하 (With 아이유)
#  10위 Ed Sheeran - Bad Habits
#  11위 태연 (TAEYEON) - Weekend
#  12위 전소미 - DUMB DUMB
#  13위 방탄소년단 - Permission to Dance
#  14위 조정석 - 좋아좋아
#  15위 방탄소년단 - Butter
#  16위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
#  17위 이무진 - 비와 당신
#  18위 헤이즈 (Heize) - 헤픈 우연
#  19위 경서예지 & 전건호 - 다정히 내 이름을 부르면
#  20위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
#  21위 방탄소년단 - Dynamite
#  22위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
#  23위 아이유 (IU) - 라일락
#  24위 임영웅 - 이제 나만 믿어요
#  25위 오마이걸 (OH MY GIRL) - Dun Dun Dance
#  26위 빅마마 (Big Mama) - 하루만 더
#  27위 아이유 (IU) - Celebrity
#  28위 브레이브걸스 (Brave girls) - 치맛바람 (Chi Mat Ba Ram)
#  29위 10CM - 고백
#  30위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  31위 매드 클라운 (Mad Clown) & 이해리 (다비치) - 수취인불명
#  32위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  33위 임영웅 - 다시 사랑한다면 (김필 Ver.)
#  34위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
#  35위 TWICE (트와이스) - Alcohol-Free
#  36위 임영웅 - 별빛 같은 나의 사랑아
#  37위 임영웅 - HERO
#  38위 다비치 - 사진을 보다가
#  39위 브레이브걸스 (Brave girls) - 운전만해 (We Ride)
#  40위 김대명 - 가을 우체국 앞에서
#  41위 조이 (JOY) - 안녕 (Hello)
#  42위 STAYC (스테이씨) - ASAP
#  43위 Justin Bieber - Off My Face
#  44위 임영웅 - 그대라는 사치
#  45위 임영웅 - 끝사랑
#  46위 라붐 (LABOUM) - 상상더하기
#  47위 임영웅 - Bk Love
#  48위 Pink Sweat$ - At My Worst
#  49위 SG워너비 - Timeless
#  50위 임영웅 - 잊었니
#  51위 Anne-Marie - 2002
#  52위 아이유 (IU) - 내 손을 잡아
#  53위 세븐틴 (SEVENTEEN) - 여전히 아름다운지
#  54위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  55위 조정석 - 아로하
#  56위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  57위 장범준 - 추적이는 여름 비가 되어
#  58위 아이유 (IU) - Blueming
#  59위 ASH ISLAND - 멜로디
#  60위 Stray Kids (스트레이 키즈) - 소리꾼
#  61위 etham - 12 : 45 (Stripped)
#  62위 임영웅 - 미워요
#  63위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
#  64위 MSG워너비 (정상동기) - 나를 아는 사람
#  65위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  66위 경서 - 밤하늘의 별을 (2020)
#  67위 창모 (CHANGMO) - METEOR
#  68위 BLACKPINK - Lovesick Girls
#  69위 임영웅 - 계단말고 엘리베이터
#  70위 임영웅 - 사랑의 아픔 딛고
#  71위 아이유 (IU) - 어푸 (Ah puh)
#  72위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
#  73위 환희 - 오늘은 가지마 (2021)
#  74위 Doja Cat - Kiss Me More (Feat. SZA)
#  75위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
#  76위 임영웅 - 목로주점
#  77위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
#  78위 방탄소년단 - Life Goes On
#  79위 방탄소년단 - 봄날
#  80위 미도와 파라솔 - 슈퍼스타
#  81위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
#  82위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  83위 오마이걸 (OH MY GIRL) - Dolphin
#  84위 MSG워너비 - 상상더하기
#  85위 양요섭 & 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
#  86위 Standing Egg (스탠딩 에그) - 오래된 노래
#  87위 John K - parachute
#  88위 Bruno Mars & Anderson .Paak & Silk Sonic - Leave The Door Open
#  89위 장범준 - 잠이 오질 않네요
#  90위 Maroon 5 - Memories
#  91위 백지영 & 이홍기 (FT아일랜드) - 다시 사랑할 수 있을까
#  92위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  93위 장범준 - 고백
#  94위 경서예지 - 은하수를 닮은 너에게 (Feat. 몰리디)
#  95위 정동하 - 추억은 만남보다 이별에 남아
#  96위 장범준 - 나는 너 좋아
#  97위 Tones And I - Dance Monkey
#  98위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
#  99위 이예준 - 그날에 나는 맘이 편했을까
# 100위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 101위 선우정아 - 도망가자 (Run With Me)
# 102위 Christopher - Bad
# 103위 PATEKO (파테코) - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 104위 아이유 (IU) - Coin
# 105위 원슈타인 - 밤이 되니까
# 106위 카더가든 - 가까운 듯 먼 그대여
# 107위 전미도 - 사랑하게 될 줄 알았어
# 108위 Sam Ryder - Tiny Riot
# 109위 김호중 - 만개 (Prod. 신지후)
# 110위 정경호 - 회상
# 111위 10CM - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 112위 SG워너비 - 라라라
# 113위 로꼬 & 이성경 - 러브 (Prod. by 로코베리)
# 114위 Dua Lipa - Don't Start Now
# 115위 #안녕 - 너의 번호를 누르고 (Prod. by 영화처럼)
# 116위 숀 (SHAUN) - Way Back Home
# 117위 Stellar - Ashes
# 118위 Lauv - Paris In The Rain
# 119위 미도와 파라솔 - 넌 내게 반했어 (Drama Ver.)
# 120위 헤이즈 (Heize) - 비도 오고 그래서 (Feat. 신용재)
# 121위 김호중 - 나보다 더 사랑해요
# 122위 경서예지 - 사실 나는 (Feat. 전건호)
# 123위 방탄소년단 - IDOL
# 124위 허각 - 우린 어쩌다 헤어진 걸까
# 125위 Ed Sheeran - Shape Of You
# 126위 방탄소년단 - ON
# 127위 오반 (OVAN) - 어떻게 지내 (Prod. by VAN.C)
# 128위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 129위 호미들 - 사이렌
# 130위 Stray Kids (스트레이 키즈) - DOMINO
# 131위 노을 - 늦은 밤 너의 집 앞 골목길에서
# 132위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 133위 규현 (KYUHYUN) - 화려하지 않은 고백
# 134위 오반 (OVAN) - 허리춤
# 135위 아이유 (IU) - 밤편지
# 136위 로제 (ROSE) - On The Ground
# 137위 SG워너비 - 넌 좋은 사람
# 138위 Stray Kids (스트레이 키즈) - CHEESE
# 139위 청하 & Christopher - Bad Boy
# 140위 Stray Kids (스트레이 키즈) - The View
# 141위 허각 - 고백 (바른연애 길잡이 X 허각)
# 142위 Stray Kids (스트레이 키즈) - 씩 (SSICK)
# 143위 방탄소년단 - DNA
# 144위 Stray Kids (스트레이 키즈) - 말할 수 없는 비밀
# 145위 Stray Kids (스트레이 키즈) - Silent Cry
# 146위 방탄소년단 - 소우주 (Mikrokosmos)
# 147위 폴킴 - 안녕
# 148위 잔나비 - 주저하는 연인들을 위해
# 149위 성시경 - 너의 모든 순간
# 150위 ITZY (있지) - 마.피.아. In the morning
# 151위 Stray Kids (스트레이 키즈) - Star Lost
# 152위 Stray Kids (스트레이 키즈) - Gone Away (한 & 승민 & 아이엔)
# 153위 Stray Kids (스트레이 키즈) - 좋아해서 미안
# 154위 아이유 (IU) - 마음을 드려요
# 155위 규현 (KYUHYUN) - 별이 빛나는 밤에
# 156위 BLACKPINK - How You Like That
# 157위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 158위 김호중 - 고맙소
# 159위 다비치 - 그냥 안아달란 말야
# 160위 가호 (Gaho) - 시작
# 161위 Conan Gray - Maniac
# 162위 Stray Kids (스트레이 키즈) - Surfin' (리노 & 창빈 & 필릭스)
# 163위 헤이즈 (Heize) & 펀치 (Punch) - 밤하늘의 저 별처럼
# 164위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 165위 Stray Kids (스트레이 키즈) - Back Door
# 166위 김호중 - 아무도 잠들지 마라 (Nessun Dorma)
# 167위 Stray Kids (스트레이 키즈) - 강박 (방찬 & 현진)
# 168위 김호중 - 살았소
# 169위 Stray Kids (스트레이 키즈) - WOLFGANG
# 170위 aespa - Black Mamba
# 171위 Stray Kids (스트레이 키즈) - 애
# 172위 이무진 - 담아 갈게
# 173위 비투비 - Outsider
# 174위 폴킴 - 너를 만나
# 175위 김호중 - 우산이 없어요
# 176위 김호중 - 할무니
# 177위 임창정 - 힘든 건 사랑이 아니다
# 178위 Marshmello & Jonas Brothers - Leave Before You Love Me
# 179위 Billie Eilish - bad guy
# 180위 Ariana Grande & Justin Bieber - Stuck With U
# 181위 Alan Walker & Noah Cyrus & Digital Farm Animals - All Falls Down (Feat. Juliander)
# 182위 로꼬 - 이대로만 (Feat. 죠지)
# 183위 Alan Walker & Sabrina Carpenter & Farruko - On My Way
# 184위 케이시 (Kassy) - 너의 발걸음에 빛을 비춰줄게 (Prod. by 조영수)
# 185위 전상근 - 너무 보고싶어
# 186위 아이유 (IU) - Love poem
# 187위 Jeremy Zucker - Comethru
# 188위 SG워너비 - 내사람 : Partner For Life
# 189위 방탄소년단 - FAKE LOVE
# 190위 태연 (TAEYEON) - 사계 (Four Seasons)
# 191위 에일리 (AILEE) - 첫눈처럼 너에게 가겠다
# 192위 키 (KEY) - Hate that... (Feat. 태연)
# 193위 유연석 - 너에게
# 194위 윤미래 - It's My Life
# 195위 V.O.S - 제자리 걸음
# 196위 하성운 - Thank you
# 197위 Ruel - Painkiller
# 198위 김호중 & 오현우 - 소녀
# 199위 이보람 (씨야) - 사랑하니까 (2021)
# 200위 칸토 - I'm So Fine (Feat. 김호중)

# %%
# 크롤링한 결과를 텍스트 파일로 저장한다.
file = open('./output/genieTOP200.txt', 'w')
# 위의 문장처럼 실행했는데 cp949 어쩌고 하면서 에러가 발생되면 open() 함수를 아래와 같이 수정한다.
# file = open('./output/genieTOP200.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Genie 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(200):
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, genie[i][0], genie[i][1]))          
file.close()
print('genieTOP200.txt 파일로 쓰기 완료')
# Out:
# genieTOP200.txt 파일로 쓰기 완료

# %%
try:
    file = open('./output/genieTOP200.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('genieTOP200.txt 파일에서 읽기 완료')
except FileNotFoundError:
    print('디스크에 genieTOP200.txt 파일이 없습니다.')
# Out:
# 2021-09-03 21:29:35.061096 현재 Genie 뮤직 실시간 TOP 100
# 1위 The Kid LAROI & Justin Bieber - Stay
# 2위 케이윌 (K.Will) - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 3위 이무진 - 신호등
# 4위 디핵 (D-Hack) & PATEKO - OHAYO MY NIGHT
# 5위 Red Velvet (레드벨벳) - Queendom
# 6위 MSG워너비 (M.O.M) - 바라만 본다
# 7위 aespa - Next Level
# 8위 멜로망스 (MeloMance) - 고백
# 9위 AKMU (악뮤) - 낙하 (With 아이유)
# 10위 Ed Sheeran - Bad Habits
# 11위 태연 (TAEYEON) - Weekend
# 12위 전소미 - DUMB DUMB
# 13위 방탄소년단 - Permission to Dance
# 14위 조정석 - 좋아좋아
# 15위 방탄소년단 - Butter
# 16위 Justin Bieber - Peaches (Feat. Daniel Caesar & Giveon)
# 17위 이무진 - 비와 당신
# 18위 헤이즈 (Heize) - 헤픈 우연
# 19위 경서예지 & 전건호 - 다정히 내 이름을 부르면
# 20위 헤이즈 (Heize) - 비가 오는 날엔 (2021)
# 21위 방탄소년단 - Dynamite
# 22위 브레이브걸스 (Brave girls) - 롤린 (Rollin')
# 23위 아이유 (IU) - 라일락
# 24위 임영웅 - 이제 나만 믿어요
# 25위 오마이걸 (OH MY GIRL) - Dun Dun Dance
# 26위 빅마마 (Big Mama) - 하루만 더
# 27위 아이유 (IU) - Celebrity
# 28위 브레이브걸스 (Brave girls) - 치맛바람 (Chi Mat Ba Ram)
# 29위 10CM - 고백
# 30위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 31위 매드 클라운 (Mad Clown) & 이해리 (다비치) - 수취인불명
# 32위 Jawsh 685 & Jason Derulo & 방탄소년단 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 33위 임영웅 - 다시 사랑한다면 (김필 Ver.)
# 34위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID & Paul Blanco)
# 35위 TWICE (트와이스) - Alcohol-Free
# 36위 임영웅 - 별빛 같은 나의 사랑아
# 37위 임영웅 - HERO
# 38위 다비치 - 사진을 보다가
# 39위 브레이브걸스 (Brave girls) - 운전만해 (We Ride)
# 40위 김대명 - 가을 우체국 앞에서
# 41위 조이 (JOY) - 안녕 (Hello)
# 42위 STAYC (스테이씨) - ASAP
# 43위 Justin Bieber - Off My Face
# 44위 임영웅 - 그대라는 사치
# 45위 임영웅 - 끝사랑
# 46위 라붐 (LABOUM) - 상상더하기
# 47위 임영웅 - Bk Love
# 48위 Pink Sweat$ - At My Worst
# 49위 SG워너비 - Timeless
# 50위 임영웅 - 잊었니
# 51위 Anne-Marie - 2002
# 52위 아이유 (IU) - 내 손을 잡아
# 53위 세븐틴 (SEVENTEEN) - 여전히 아름다운지
# 54위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
# 55위 조정석 - 아로하
# 56위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 57위 장범준 - 추적이는 여름 비가 되어
# 58위 아이유 (IU) - Blueming
# 59위 ASH ISLAND - 멜로디
# 60위 Stray Kids (스트레이 키즈) - 소리꾼
# 61위 etham - 12 : 45 (Stripped)
# 62위 임영웅 - 미워요
# 63위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 64위 MSG워너비 (정상동기) - 나를 아는 사람
# 65위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 66위 경서 - 밤하늘의 별을 (2020)
# 67위 창모 (CHANGMO) - METEOR
# 68위 BLACKPINK - Lovesick Girls
# 69위 임영웅 - 계단말고 엘리베이터
# 70위 임영웅 - 사랑의 아픔 딛고
# 71위 아이유 (IU) - 어푸 (Ah puh)
# 72위 폴킴 - 모든 날, 모든 순간 (Every day, Every Moment)
# 73위 환희 - 오늘은 가지마 (2021)
# 74위 Doja Cat - Kiss Me More (Feat. SZA)
# 75위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
# 76위 임영웅 - 목로주점
# 77위 아이유 (IU) - 에잇 (Prod. & Feat. SUGA of BTS)
# 78위 방탄소년단 - Life Goes On
# 79위 방탄소년단 - 봄날
# 80위 미도와 파라솔 - 슈퍼스타
# 81위 미란이 (Mirani) & 먼치맨 (MUNCHMAN) & Khundi Panda & 머쉬베놈 (MUSHVENOM) - VVS (Feat. JUSTHIS) (Prod. by GroovyRoom)
# 82위 AKMU (악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 83위 오마이걸 (OH MY GIRL) - Dolphin
# 84위 MSG워너비 - 상상더하기
# 85위 양요섭 & 정은지 - LOVE DAY (2021) (바른연애 길잡이 X 양요섭, 정은지)
# 86위 Standing Egg (스탠딩 에그) - 오래된 노래
# 87위 John K - parachute
# 88위 Bruno Mars & Anderson .Paak & Silk Sonic - Leave The Door Open
# 89위 장범준 - 잠이 오질 않네요
# 90위 Maroon 5 - Memories
# 91위 백지영 & 이홍기 (FT아일랜드) - 다시 사랑할 수 있을까
# 92위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
# 93위 장범준 - 고백
# 94위 경서예지 - 은하수를 닮은 너에게 (Feat. 몰리디)
# 95위 정동하 - 추억은 만남보다 이별에 남아
# 96위 장범준 - 나는 너 좋아
# 97위 Tones And I - Dance Monkey
# 98위 마크툽 (Maktub) - 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 99위 이예준 - 그날에 나는 맘이 편했을까
# 100위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 101위 선우정아 - 도망가자 (Run With Me)
# 102위 Christopher - Bad
# 103위 PATEKO (파테코) - Rainy day (Feat. ASH ISLAND & Skinny Brown)
# 104위 아이유 (IU) - Coin
# 105위 원슈타인 - 밤이 되니까
# 106위 카더가든 - 가까운 듯 먼 그대여
# 107위 전미도 - 사랑하게 될 줄 알았어
# 108위 Sam Ryder - Tiny Riot
# 109위 김호중 - 만개 (Prod. 신지후)
# 110위 정경호 - 회상
# 111위 10CM - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 112위 SG워너비 - 라라라
# 113위 로꼬 & 이성경 - 러브 (Prod. by 로코베리)
# 114위 Dua Lipa - Don't Start Now
# 115위 #안녕 - 너의 번호를 누르고 (Prod. by 영화처럼)
# 116위 숀 (SHAUN) - Way Back Home
# 117위 Stellar - Ashes
# 118위 Lauv - Paris In The Rain
# 119위 미도와 파라솔 - 넌 내게 반했어 (Drama Ver.)
# 120위 헤이즈 (Heize) - 비도 오고 그래서 (Feat. 신용재)
# 121위 김호중 - 나보다 더 사랑해요
# 122위 경서예지 - 사실 나는 (Feat. 전건호)
# 123위 방탄소년단 - IDOL
# 124위 허각 - 우린 어쩌다 헤어진 걸까
# 125위 Ed Sheeran - Shape Of You
# 126위 방탄소년단 - ON
# 127위 오반 (OVAN) - 어떻게 지내 (Prod. by VAN.C)
# 128위 조이 (JOY) - 좋은 사람 있으면 소개시켜줘
# 129위 호미들 - 사이렌
# 130위 Stray Kids (스트레이 키즈) - DOMINO
# 131위 노을 - 늦은 밤 너의 집 앞 골목길에서
# 132위 오마이걸 (OH MY GIRL) - 살짝 설렜어 (Nonstop)
# 133위 규현 (KYUHYUN) - 화려하지 않은 고백
# 134위 오반 (OVAN) - 허리춤
# 135위 아이유 (IU) - 밤편지
# 136위 로제 (ROSE) - On The Ground
# 137위 SG워너비 - 넌 좋은 사람
# 138위 Stray Kids (스트레이 키즈) - CHEESE
# 139위 청하 & Christopher - Bad Boy
# 140위 Stray Kids (스트레이 키즈) - The View
# 141위 허각 - 고백 (바른연애 길잡이 X 허각)
# 142위 Stray Kids (스트레이 키즈) - 씩 (SSICK)
# 143위 방탄소년단 - DNA
# 144위 Stray Kids (스트레이 키즈) - 말할 수 없는 비밀
# 145위 Stray Kids (스트레이 키즈) - Silent Cry
# 146위 방탄소년단 - 소우주 (Mikrokosmos)
# 147위 폴킴 - 안녕
# 148위 잔나비 - 주저하는 연인들을 위해
# 149위 성시경 - 너의 모든 순간
# 150위 ITZY (있지) - 마.피.아. In the morning
# 151위 Stray Kids (스트레이 키즈) - Star Lost
# 152위 Stray Kids (스트레이 키즈) - Gone Away (한 & 승민 & 아이엔)
# 153위 Stray Kids (스트레이 키즈) - 좋아해서 미안
# 154위 아이유 (IU) - 마음을 드려요
# 155위 규현 (KYUHYUN) - 별이 빛나는 밤에
# 156위 BLACKPINK - How You Like That
# 157위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 158위 김호중 - 고맙소
# 159위 다비치 - 그냥 안아달란 말야
# 160위 가호 (Gaho) - 시작
# 161위 Conan Gray - Maniac
# 162위 Stray Kids (스트레이 키즈) - Surfin' (리노 & 창빈 & 필릭스)
# 163위 헤이즈 (Heize) & 펀치 (Punch) - 밤하늘의 저 별처럼
# 164위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# 165위 Stray Kids (스트레이 키즈) - Back Door
# 166위 김호중 - 아무도 잠들지 마라 (Nessun Dorma)
# 167위 Stray Kids (스트레이 키즈) - 강박 (방찬 & 현진)
# 168위 김호중 - 살았소
# 169위 Stray Kids (스트레이 키즈) - WOLFGANG
# 170위 aespa - Black Mamba
# 171위 Stray Kids (스트레이 키즈) - 애
# 172위 이무진 - 담아 갈게
# 173위 비투비 - Outsider
# 174위 폴킴 - 너를 만나
# 175위 김호중 - 우산이 없어요
# 176위 김호중 - 할무니
# 177위 임창정 - 힘든 건 사랑이 아니다
# 178위 Marshmello & Jonas Brothers - Leave Before You Love Me
# 179위 Billie Eilish - bad guy
# 180위 Ariana Grande & Justin Bieber - Stuck With U
# 181위 Alan Walker & Noah Cyrus & Digital Farm Animals - All Falls Down (Feat. Juliander)
# 182위 로꼬 - 이대로만 (Feat. 죠지)
# 183위 Alan Walker & Sabrina Carpenter & Farruko - On My Way
# 184위 케이시 (Kassy) - 너의 발걸음에 빛을 비춰줄게 (Prod. by 조영수)
# 185위 전상근 - 너무 보고싶어
# 186위 아이유 (IU) - Love poem
# 187위 Jeremy Zucker - Comethru
# 188위 SG워너비 - 내사람 : Partner For Life
# 189위 방탄소년단 - FAKE LOVE
# 190위 태연 (TAEYEON) - 사계 (Four Seasons)
# 191위 에일리 (AILEE) - 첫눈처럼 너에게 가겠다
# 192위 키 (KEY) - Hate that... (Feat. 태연)
# 193위 유연석 - 너에게
# 194위 윤미래 - It's My Life
# 195위 V.O.S - 제자리 걸음
# 196위 하성운 - Thank you
# 197위 Ruel - Painkiller
# 198위 김호중 & 오현우 - 소녀
# 199위 이보람 (씨야) - 사랑하니까 (2021)
# 200위 칸토 - I'm So Fine (Feat. 김호중)
# genieTOP200.txt 파일에서 읽기 완료

# %%
import warnings
warnings.filterwarnings(action='ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2021-09-03 19:36:07.565309

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
# print(request)
html = request.text
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))

for i in range(len(titles)):
    # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip())) # 사용가능
    # print('{0:3d}위 {1}'.format(i + 1, titles[i].text.split('\n')[1])) # 사용가능
    print('{0:3d}위 {1}'.format(i + 1, titles[i].text.strip().split('\n')[0])) # 사용가능
# Out:
#   1위 STAY
#   2위 Queendom
#   3위 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   4위 신호등
#   5위 DUMB DUMB
#   6위 Next Level
#   7위 고백
#   8위 낙하 (with 아이유)
#   9위 Permission to Dance
#  10위 Weekend
#  11위 Bad Habits
#  12위 바라만 본다
#  13위 OHAYO MY NIGHT
#  14위 가까운 듯 먼 그대여
#  15위 Butter
#  16위 비가 오는 날엔 (2021)
#  17위 좋아좋아
#  18위 Dun Dun Dance
#  19위 Hate that... (Feat. 태연)
#  20위 고백
#  21위 Peaches (feat. Daniel Caesar, Giveon)
#  22위 헤픈 우연
#  23위 ASAP
#  24위 Not Friends (Sung by 희진, 김립, 진솔, 이브) (Prod. 라이언전)
#  25위 Alcohol-Free
#  26위 회상
#  27위 라일락
#  28위 넌 내게 반했어 (Drama Ver.)
#  29위 고백
#  30위 Celebrity
#  31위 이대로만 (Feat. 죠지)
#  32위 수취인불명
#  33위 벌써 일년 (Drama Ver.)
#  34위 ONLY
#  35위 하루만 더
#  36위 Loving You Girl (feat. Hkeem)
#  37위 Dynamite
#  38위 비와 당신
#  39위 You can't sit with us
#  40위 Off My Face
#  41위 여전히 아름다운지
#  42위 Talk & Talk
#  43위 Leave Before You Love Me
#  44위 롤린 (Rollin')
#  45위 It's My Life
#  46위 에잇(Prod.&Feat. SUGA of BTS)
#  47위 이젠 잊기로 해요 (Drama Ver.)
#  48위 비와 당신 (Drama Ver.)
#  49위 내 손을 잡아
#  50위 나인가요
#  51위 다정히 내 이름을 부르면
#  52위 안녕 (Hello)
#  53위 Lovesick Girls
#  54위 너에게
#  55위 나는 너 좋아
#  56위 Kiss Me More (feat. SZA)
#  57위 가을 우체국 앞에서
#  58위 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  59위 Black Mamba
#  60위 Thank you
#  61위 나는 너 좋아 (Drama Ver.)
#  62위 상상더하기
#  63위 슈퍼스타
#  64위 제자리 걸음
#  65위 Outsider
#  66위 운전만해 (We Ride)
#  67위 치맛바람 (Chi Mat Ba Ram)
#  68위 전쟁터 (with 이선희)
#  69위 뚫고 지나가요
#  70위 어푸 (Ah puh)
#  71위 째깍 째깍 째깍 (with Beenzino)
#  72위 Dolphin
#  73위 사진을 보다가
#  74위 Blueming
#  75위 Timeless
#  76위 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  77위 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  78위 넌 좋은 사람
#  79위 WE GO
#  80위 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  81위 술버릇 (운전만해 그후)
#  82위 Savage Love (Laxed - Siren Beat) (BTS Remix)
#  83위 parachute
#  84위 밤이 되니까
#  85위 THRILL RIDE
#  86위 도망가자 (Run With Me)
#  87위 추적이는 여름 비가 되어
#  88위 How You Like That
#  89위 Coin
#  90위 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  91위 Stupid love song (with Crush)
#  92위 눈물을 훔친다 (금혼령 X 김종국)
#  93위 Leave The Door Open
#  94위 I'm Gonna Love You (Feat. 원슈타인)
#  95위 유희
#  96위 Life Goes On
#  97위 Tiny Riot
#  98위 BENCH (with Zion.T)
#  99위 나를 아는 사람
# 100위 ONE ROOM

# %%
# 아티스트 크롤링
artists = soup.findAll('p', {'class', 'artist'})
# print(artists)
# print(len(artists))

for i in range(len(artists)):
    # print(artists[i].text.strip())
    # print(artists[i].text.split('\n'))
    print('{0:3d}위 {1}'.format(i + 1, artists[i].text.strip().split('\n')[0])) # 사용가능
# Out:
#   1위 The Kid LAROI
#   2위 Red Velvet (레드벨벳)
#   3위 케이윌
#   4위 이무진
#   5위 전소미
#   6위 aespa
#   7위 멜로망스(MeloMance)
#   8위 AKMU(악뮤)
#   9위 방탄소년단
#  10위 태연 (TAEYEON)
#  11위 Ed Sheeran(에드 시런)
#  12위 MSG워너비(M.O.M)
#  13위 디핵(D-Hack)
#  14위 카더가든
#  15위 방탄소년단
#  16위 헤이즈(Heize)
#  17위 조정석
#  18위 오마이걸(OH MY GIRL)
#  19위 키 (KEY)
#  20위 장범준
#  21위 Justin Bieber(저스틴 비버)
#  22위 헤이즈(Heize)
#  23위 STAYC(스테이씨)
#  24위 이달의 소녀
#  25위 TWICE (트와이스)
#  26위 정경호
#  27위 아이유(IU)
#  28위 미도와 파라솔
#  29위 10CM
#  30위 아이유(IU)
#  31위 로꼬
#  32위 매드 클라운(Mad Clown)
#  33위 미도와 파라솔
#  34위 이하이
#  35위 빅마마(Big Mama)
#  36위 Peder Elias
#  37위 방탄소년단
#  38위 이무진
#  39위 선미
#  40위 Justin Bieber(저스틴 비버)
#  41위 세븐틴(SEVENTEEN)
#  42위 프로미스나인
#  43위 Marshmello(마시멜로)
#  44위 브레이브걸스(Brave Girls)
#  45위 윤미래
#  46위 아이유(IU)
#  47위 미도와 파라솔
#  48위 미도와 파라솔
#  49위 아이유(IU)
#  50위 백현(BAEKHYUN)
#  51위 경서예지
#  52위 조이 (JOY)
#  53위 BLACKPINK
#  54위 유연석
#  55위 장범준
#  56위 Doja Cat(도자 캣)
#  57위 김대명
#  58위 에픽하이 (EPIK HIGH)
#  59위 aespa
#  60위 하성운
#  61위 미도와 파라솔
#  62위 라붐(LABOUM)
#  63위 미도와 파라솔
#  64위 V.O.S.
#  65위 비투비
#  66위 브레이브걸스(Brave Girls)
#  67위 브레이브걸스(Brave Girls)
#  68위 AKMU(악뮤)
#  69위 DAY6 (Even of Day)
#  70위 아이유(IU)
#  71위 AKMU(악뮤)
#  72위 오마이걸(OH MY GIRL)
#  73위 다비치
#  74위 아이유(IU)
#  75위 SG워너비
#  76위 호미들
#  77위 AKMU(악뮤)
#  78위 SG워너비
#  79위 프로미스나인
#  80위 장범준
#  81위 브레이브걸스(Brave Girls)
#  82위 Jawsh 685
#  83위 John K
#  84위 원슈타인
#  85위 더보이즈(THE BOYZ)
#  86위 선우정아(Sunwoojunga)
#  87위 장범준
#  88위 BLACKPINK
#  89위 아이유(IU)
#  90위 방탄소년단
#  91위 AKMU(악뮤)
#  92위 김종국
#  93위 Bruno Mars(브루노 마스)
#  94위 디오 (D.O.)
#  95위 넬(NELL)
#  96위 방탄소년단
#  97위 Sam Ryder
#  98위 AKMU(악뮤)
#  99위 MSG워너비(정상동기)
# 100위 이기찬

# %%
print('{} 현재'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2021-09-03 19:36:29.653172 현재
#   1위 The Kid LAROI - STAY
#   2위 Red Velvet (레드벨벳) - Queendom
#   3위 케이윌 - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
#   4위 이무진 - 신호등
#   5위 전소미 - DUMB DUMB
#   6위 aespa - Next Level
#   7위 멜로망스(MeloMance) - 고백
#   8위 AKMU(악뮤) - 낙하 (with 아이유)
#   9위 방탄소년단 - Permission to Dance
#  10위 태연 (TAEYEON) - Weekend
#  11위 Ed Sheeran(에드 시런) - Bad Habits
#  12위 MSG워너비(M.O.M) - 바라만 본다
#  13위 디핵(D-Hack) - OHAYO MY NIGHT
#  14위 카더가든 - 가까운 듯 먼 그대여
#  15위 방탄소년단 - Butter
#  16위 헤이즈(Heize) - 비가 오는 날엔 (2021)
#  17위 조정석 - 좋아좋아
#  18위 오마이걸(OH MY GIRL) - Dun Dun Dance
#  19위 키 (KEY) - Hate that... (Feat. 태연)
#  20위 장범준 - 고백
#  21위 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
#  22위 헤이즈(Heize) - 헤픈 우연
#  23위 STAYC(스테이씨) - ASAP
#  24위 이달의 소녀 - Not Friends (Sung by 희진, 김립, 진솔, 이브) (Prod. 라이언전)
#  25위 TWICE (트와이스) - Alcohol-Free
#  26위 정경호 - 회상
#  27위 아이유(IU) - 라일락
#  28위 미도와 파라솔 - 넌 내게 반했어 (Drama Ver.)
#  29위 10CM - 고백
#  30위 아이유(IU) - Celebrity
#  31위 로꼬 - 이대로만 (Feat. 죠지)
#  32위 매드 클라운(Mad Clown) - 수취인불명
#  33위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
#  34위 이하이 - ONLY
#  35위 빅마마(Big Mama) - 하루만 더
#  36위 Peder Elias - Loving You Girl (feat. Hkeem)
#  37위 방탄소년단 - Dynamite
#  38위 이무진 - 비와 당신
#  39위 선미 - You can't sit with us
#  40위 Justin Bieber(저스틴 비버) - Off My Face
#  41위 세븐틴(SEVENTEEN) - 여전히 아름다운지
#  42위 프로미스나인 - Talk & Talk
#  43위 Marshmello(마시멜로) - Leave Before You Love Me
#  44위 브레이브걸스(Brave Girls) - 롤린 (Rollin')
#  45위 윤미래 - It's My Life
#  46위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  47위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
#  48위 미도와 파라솔 - 비와 당신 (Drama Ver.)
#  49위 아이유(IU) - 내 손을 잡아
#  50위 백현(BAEKHYUN) - 나인가요
#  51위 경서예지 - 다정히 내 이름을 부르면
#  52위 조이 (JOY) - 안녕 (Hello)
#  53위 BLACKPINK - Lovesick Girls
#  54위 유연석 - 너에게
#  55위 장범준 - 나는 너 좋아
#  56위 Doja Cat(도자 캣) - Kiss Me More (feat. SZA)
#  57위 김대명 - 가을 우체국 앞에서
#  58위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
#  59위 aespa - Black Mamba
#  60위 하성운 - Thank you
#  61위 미도와 파라솔 - 나는 너 좋아 (Drama Ver.)
#  62위 라붐(LABOUM) - 상상더하기
#  63위 미도와 파라솔 - 슈퍼스타
#  64위 V.O.S. - 제자리 걸음
#  65위 비투비 - Outsider
#  66위 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
#  67위 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
#  68위 AKMU(악뮤) - 전쟁터 (with 이선희)
#  69위 DAY6 (Even of Day) - 뚫고 지나가요
#  70위 아이유(IU) - 어푸 (Ah puh)
#  71위 AKMU(악뮤) - 째깍 째깍 째깍 (with Beenzino)
#  72위 오마이걸(OH MY GIRL) - Dolphin
#  73위 다비치 - 사진을 보다가
#  74위 아이유(IU) - Blueming
#  75위 SG워너비 - Timeless
#  76위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
#  77위 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  78위 SG워너비 - 넌 좋은 사람
#  79위 프로미스나인 - WE GO
#  80위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  81위 브레이브걸스(Brave Girls) - 술버릇 (운전만해 그후)
#  82위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  83위 John K - parachute
#  84위 원슈타인 - 밤이 되니까
#  85위 더보이즈(THE BOYZ) - THRILL RIDE
#  86위 선우정아(Sunwoojunga) - 도망가자 (Run With Me)
#  87위 장범준 - 추적이는 여름 비가 되어
#  88위 BLACKPINK - How You Like That
#  89위 아이유(IU) - Coin
#  90위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  91위 AKMU(악뮤) - Stupid love song (with Crush)
#  92위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
#  93위 Bruno Mars(브루노 마스) - Leave The Door Open
#  94위 디오 (D.O.) - I'm Gonna Love You (Feat. 원슈타인)
#  95위 넬(NELL) - 유희
#  96위 방탄소년단 - Life Goes On
#  97위 Sam Ryder - Tiny Riot
#  98위 AKMU(악뮤) - BENCH (with Zion.T)
#  99위 MSG워너비(정상동기) - 나를 아는 사람
# 100위 이기찬 - ONE ROOM

# %%
# 크롤링한 결과를 텍스트 파일로 저장한다.
file = open('./output/bugsTOP100.txt', 'w')
# 위의 문장처럼 실행했는데 cp949 어쩌고 하면서 에러가 발생되면 open() 함수를 아래와 같이 수정한다.
# file = open('./output/bugsTOP100.txt', 'w', -1, 'UTF-8')
file.write('{} 현재 Bugs 뮤직 실시간 TOP 100\n'.format(dt.now()))
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    file.write('{0:3d}위 {1} - {2}\n'.format(i + 1, artist, title))          
file.close()
print('bugsTOP100.txt 파일로 쓰기 완료')
# Out:
# bugsTOP100.txt 파일로 쓰기 완료

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('./output/bugsTOP100.txt', 'r')
    lines = file.readlines()
    for line in lines:
        print(line.strip())
    file.close()
    print('bugsTOP100.txt 파일에서 읽기 완료')
except FileNotFoundError:
    print('디스크에 bugsTOP100.txt 파일이 없습니다.')
# Out:
# 2021-09-03 19:48:10.960684 현재 Bugs 뮤직 실시간 TOP 100
# 1위 The Kid LAROI - STAY
# 2위 Red Velvet (레드벨벳) - Queendom
# 3위 케이윌 - 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 4위 이무진 - 신호등
# 5위 전소미 - DUMB DUMB
# 6위 aespa - Next Level
# 7위 멜로망스(MeloMance) - 고백
# 8위 AKMU(악뮤) - 낙하 (with 아이유)
# 9위 방탄소년단 - Permission to Dance
# 10위 태연 (TAEYEON) - Weekend
# 11위 Ed Sheeran(에드 시런) - Bad Habits
# 12위 MSG워너비(M.O.M) - 바라만 본다
# 13위 디핵(D-Hack) - OHAYO MY NIGHT
# 14위 카더가든 - 가까운 듯 먼 그대여
# 15위 방탄소년단 - Butter
# 16위 헤이즈(Heize) - 비가 오는 날엔 (2021)
# 17위 조정석 - 좋아좋아
# 18위 오마이걸(OH MY GIRL) - Dun Dun Dance
# 19위 키 (KEY) - Hate that... (Feat. 태연)
# 20위 장범준 - 고백
# 21위 Justin Bieber(저스틴 비버) - Peaches (feat. Daniel Caesar, Giveon)
# 22위 헤이즈(Heize) - 헤픈 우연
# 23위 STAYC(스테이씨) - ASAP
# 24위 이달의 소녀 - Not Friends (Sung by 희진, 김립, 진솔, 이브) (Prod. 라이언전)
# 25위 TWICE (트와이스) - Alcohol-Free
# 26위 정경호 - 회상
# 27위 아이유(IU) - 라일락
# 28위 미도와 파라솔 - 넌 내게 반했어 (Drama Ver.)
# 29위 10CM - 고백
# 30위 아이유(IU) - Celebrity
# 31위 로꼬 - 이대로만 (Feat. 죠지)
# 32위 매드 클라운(Mad Clown) - 수취인불명
# 33위 미도와 파라솔 - 벌써 일년 (Drama Ver.)
# 34위 이하이 - ONLY
# 35위 빅마마(Big Mama) - 하루만 더
# 36위 Peder Elias - Loving You Girl (feat. Hkeem)
# 37위 방탄소년단 - Dynamite
# 38위 이무진 - 비와 당신
# 39위 선미 - You can't sit with us
# 40위 Justin Bieber(저스틴 비버) - Off My Face
# 41위 세븐틴(SEVENTEEN) - 여전히 아름다운지
# 42위 프로미스나인 - Talk & Talk
# 43위 Marshmello(마시멜로) - Leave Before You Love Me
# 44위 브레이브걸스(Brave Girls) - 롤린 (Rollin')
# 45위 윤미래 - It's My Life
# 46위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
# 47위 미도와 파라솔 - 이젠 잊기로 해요 (Drama Ver.)
# 48위 미도와 파라솔 - 비와 당신 (Drama Ver.)
# 49위 아이유(IU) - 내 손을 잡아
# 50위 백현(BAEKHYUN) - 나인가요
# 51위 경서예지 - 다정히 내 이름을 부르면
# 52위 조이 (JOY) - 안녕 (Hello)
# 53위 BLACKPINK - Lovesick Girls
# 54위 유연석 - 너에게
# 55위 장범준 - 나는 너 좋아
# 56위 Doja Cat(도자 캣) - Kiss Me More (feat. SZA)
# 57위 김대명 - 가을 우체국 앞에서
# 58위 에픽하이 (EPIK HIGH) - 비 오는 날 듣기 좋은 노래 (Feat. Colde)
# 59위 aespa - Black Mamba
# 60위 하성운 - Thank you
# 61위 미도와 파라솔 - 나는 너 좋아 (Drama Ver.)
# 62위 라붐(LABOUM) - 상상더하기
# 63위 미도와 파라솔 - 슈퍼스타
# 64위 V.O.S. - 제자리 걸음
# 65위 비투비 - Outsider
# 66위 브레이브걸스(Brave Girls) - 운전만해 (We Ride)
# 67위 브레이브걸스(Brave Girls) - 치맛바람 (Chi Mat Ba Ram)
# 68위 AKMU(악뮤) - 전쟁터 (with 이선희)
# 69위 DAY6 (Even of Day) - 뚫고 지나가요
# 70위 아이유(IU) - 어푸 (Ah puh)
# 71위 AKMU(악뮤) - 째깍 째깍 째깍 (with Beenzino)
# 72위 오마이걸(OH MY GIRL) - Dolphin
# 73위 다비치 - 사진을 보다가
# 74위 아이유(IU) - Blueming
# 75위 SG워너비 - Timeless
# 76위 호미들 - 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 77위 AKMU(악뮤) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 78위 SG워너비 - 넌 좋은 사람
# 79위 프로미스나인 - WE GO
# 80위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# 81위 브레이브걸스(Brave Girls) - 술버릇 (운전만해 그후)
# 82위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
# 83위 John K - parachute
# 84위 원슈타인 - 밤이 되니까
# 85위 더보이즈(THE BOYZ) - THRILL RIDE
# 86위 선우정아(Sunwoojunga) - 도망가자 (Run With Me)
# 87위 장범준 - 추적이는 여름 비가 되어
# 88위 BLACKPINK - How You Like That
# 89위 아이유(IU) - Coin
# 90위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 91위 AKMU(악뮤) - Stupid love song (with Crush)
# 92위 김종국 - 눈물을 훔친다 (금혼령 X 김종국)
# 93위 Bruno Mars(브루노 마스) - Leave The Door Open
# 94위 디오 (D.O.) - I'm Gonna Love You (Feat. 원슈타인)
# 95위 넬(NELL) - 유희
# 96위 방탄소년단 - Life Goes On
# 97위 Sam Ryder - Tiny Riot
# 98위 AKMU(악뮤) - BENCH (with Zion.T)
# 99위 MSG워너비(정상동기) - 나를 아는 사람
# 100위 이기찬 - ONE ROOM
# bugsTOP100.txt 파일에서 읽기 완료

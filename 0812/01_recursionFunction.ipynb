# %%
from IPython.display import Image
Image('./algorithm.png')

# %%
# 인수로 정수 1개를 넘겨받아 그 숫자의 factorial을 계산하는 함수
def factorial(number):
    fact = 1
    for i in range(1, number + 1):
        fact *= i
    return fact

# %%
number = int(input('정수를 입력하세요: '))
fact = factorial(number)
print('{} factorial = {}'.format(number, fact))
# Out:
# 정수를 입력하세요: 5
# 5 factorial = 120

# %%
# factorial을 계산하는 resursion 함수
def factorialResursion(number):
    if number == 1:
        return 1
    return number * factorialResursion(number - 1)

# %% [markdown]
# number에 5가 넘어왔을 때 함수가 실행되는 순서
# 5 * factorialResursion(4)
# 5 * (4 * factorialResursion(3))
# 5 * (4 * (3 * factorialResursion(2)))
# 5 * (4 * (3 * (2 * factorialResursion(1))))
# 5 * (4 * (3 * (2 * 1)))
# ***
# 5 * (4 * (3 * 2))
# 5 * (4 * 6)
# 5 * 24
# 120

# %%
number = int(input('정수를 입력하세요: '))
fact = factorialResursion(number)
print('{} factorial = {}'.format(number, fact))
# Out:
# 정수를 입력하세요: 5
# 5 factorial = 120
